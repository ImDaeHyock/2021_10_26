# %%
#모듈: 소스와 분리되어 저장된 여러 변수와 함수의 집합체, 외부와 표준으로 나뉜다.
#import 모듈명
#모듈명, 함수명() 또는 모듈명 변수명
import math
print("math.ceil(34.5):",math.ceil(34.5))
print("math.floor(34.5):",math.floor(34.5))
# Out:
# math.ceil(34.5): 35
# math.floor(34.5): 34

# %%
from math import sin, cos, ceil, floor

print(sin(10),"\t",ceil(19.4))
# Out:
# -0.5440211108893698 	 20

# %%
import math as mt    #math 를 mt라고 명명하여 사용하겠다
print("mt.sin(20): ",mt.sin(20))

from math import sin as S     #math 모듈에서 sin을 S라고 명명해 사용하겠다.
print("S(10): ",S(10))



#출력되는 숫자의 유효수 제한 어떻게 할까?
# Out:
# mt.sin(20):  0.9129452507276277
# S(10):  -0.5440211108893698

# %%
import random

random.random()  #random() 함수는 범위가 0.0 <= random < 1.0
#출력되는 수가 몇째자리 인지 확인하고 싶다!
# Out:
# 0.5592429115728474

# %%
import random
print("#random 모듈")
print("-random():", random.random())
print("-uniform(10,20):",random.uniform(10,20))
print("-randrange(10):",random.randrange(10))
print("-choice([1,2,3,4,5]):", random.choice([1,2,3,4,5]))
a_list=[1,2,3,4,5]
random.shuffle(a_list)
print("-shuffle([1,2,3,4,5]):", a_list)
print("-sample([1,2,3,4,5]), k=2):", random.sample([1,2,3,4,5],k=2))

#이 랜덤의 함수들을 어느 경우에 이용하면 좋을까?
# Out:
# #random 모듈
# -random(): 0.5700877805432664
# -uniform(10,20): 13.57186891747096
# -randrange(10): 9
# -choice([1,2,3,4,5]): 4
# -shuffle([1,2,3,4,5]): [4, 1, 5, 3, 2]
# -sample([1,2,3,4,5]), k=2): [2, 5]

# %%
#import os 운영체제와 관련된 기능을 가진 모듈

import os

print("현재 운영체제:", os.name)
print("현재 작업폴더:", os.getcwd())
print("현재 작업폴더의 디텍토리:", os.listdir())

os.mkdir("test_dir")
print("현재 작업폴더의 디텍토리:", os.listdir())

#file 삭제

#os.remove(파일명)
#os.system(명령어)

import time
time.sleep(5)
# Out:
# 현재 운영체제: nt
# 현재 작업폴더: C:\Users\TEMP\imdh\2021_10_26
# 현재 작업폴더의 디텍토리: ['.git', '.ipynb_checkpoints', '21.11.01_python_ver1.ipynb', '21_10_29_imdh.ipynb', '21_11_01_python.ipynb', '21_11_01_summary.ipynb', '21_11_02_python.ipynb', '21_11_02_summary.ipynb', '21_11_03(1).ipynb', '21_11_03_python.ipynb', 'basic.txt', 'file.txt', 'func_lab.ipynb', 'imdaehyock_paper.docx', 'imdaehyock_paper_21_10_27.docx', 'score.txt', 'test_dir']
# ------------------------------------------------------------------------
# FileExistsError                        Traceback (most recent call last)
# <ipython-input-86-0f3412196482> in <module>
#       7 print("현재 작업폴더의 디텍토리:", os.listdir())
#       8
# ----> 9 os.mkdir("test_dir")
#      10 print("현재 작업폴더의 디텍토리:", os.listdir())
#      11
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'test_dir'

# %%
#urllib 모듈 "URL"을 다루는 라이브러리

from urllib import request

web_page=request.urlopen("https://www.google.com")
output = web_page.read()

print(output)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="mPqoBBhDaIsQv2UVBsonsQ==">(function(){window.google={kEI:\'wzeCYaXdAsvR-wTs55zgCw\',kEXPI:\'0,1302536,56873,6058,207,2415,2389,2316,383,246,5,1354,4012,1238,1122516,1197772,629,12,328854,51224,16114,19398,9286,17572,1326,3532,1362,9291,3027,17581,4020,978,13228,3847,10622,21823,918,6674,1279,2212,530,149,1103,842,2194,4101,109,3405,606,2023,1777,520,14670,3227,1990,855,9,4772,7579,5097,7539,8781,908,2,3555,13142,3,576,6459,149,13975,4,1528,2304,1236,5227,576,4683,2015,13611,4764,2658,6701,655,31,5616,8012,2305,638,1494,16786,5821,2536,4094,17,3122,6,907,3,3541,1,11942,2768,1814,283,914,5990,16728,1715,2,3035,5461,5526,1931,3911,2422,2350,3502,9320,1143,1160,6699,2381,2719,4665,524,4832,8275,2,6,144,2,20
# ...

# %%
# !pip install beautifulsoup4   

#맨 앞에 !를 붙이면서 외부모듈 설치진행. cmd 창에서 진행하는 것이 정석.

# %%
from urllib import request
from bs4 import BeautifulSoup
target = request.urlopen("http://www.ycampus.co.kr/")
soup = BeautifulSoup(target)     # tag <>로 분리해서 도출
print(soup)

for script in soup.select("title"):
    print(script)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!--[if lt IE 9]>
# 		<script src="/js/css3-mediaqueries.js"></script>
# 	<![endif]-->
# <meta charset="utf-8"/>
# <meta content="영우글로벌러닝 멀티벤더 교육센터 - YGL" property="og:title"/>
# <meta content="영우글로벌러닝 멀티벤더 교육센터 - YGL - 서울시 중구 세종대로 7길 43 순화타워 대표전화. 02-6004-7000" property="og:description"/>
# <meta content="http://www.ycampus.co.kr/images/edm/newsletter/ygl.jpg" property="og:image"/>
# <meta content="영우글로벌러닝 멀티벤더 교육센터 - YGL  - 서울시 중구 세종대로 7길 43 순화타워 대표전화. 02-6004-7000" name="description"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,user-scalable=no" name="viewport"/>
# <meta content="YSIQrzRYKauZcV3i_sd2aTfZBwvl-SN8u6_Pbf9G2mI" name="google-site-verification"/>
# <link href="http://www.ycampus.co.kr/" rel="canonical"/>
# <link href="/images/favicon.ico" rel="shortcut icon"/>
# <script src="//ajax.googleapis.com/ajax/libs/webfont/1.4.10/webfont.js"></script>
# ...

# %%
from urllib import request
from bs4 import BeautifulSoup

# urlopen() 함수로 기상청의 전국 날씨를 읽습니다.
target = request.urlopen("http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108")

# BeautifulSoup을 사용해 웹 페이지를 분석합니다.
soup = BeautifulSoup(target, "html.parser")

# location 태그를 찾습니다.
for location in soup.select("location"):
    # 내부의 city, wf, tmn, tmx 태그를 찾아 출력합니다.
    print("도시:", location.select_one("city").string)
    print("날씨:", location.select_one("wf").string)
    print("최저기온:", location.select_one("tmn").string)
    print("최고기온:", location.select_one("tmx").string)
    print()
# Out:
# 도시: 서울
# 날씨: 구름많음
# 최저기온: 11
# 최고기온: 19
#
# 도시: 인천
# 날씨: 구름많음
# 최저기온: 12
# 최고기온: 18
#
# 도시: 수원
# 날씨: 구름많음
# 최저기온: 11
# 최고기온: 19
#
# 도시: 파주
# 날씨: 구름많음
# 최저기온: 6
# 최고기온: 19
#
# 도시: 이천
# 날씨: 구름많음
# 최저기온: 6
# 최고기온: 19
#
# 도시: 평택
# 날씨: 구름많음
# 최저기온: 10
# 최고기온: 19
#
# 도시: 춘천
# 날씨: 구름많음
# 최저기온: 7
# 최고기온: 18
#
# 도시: 원주
# 날씨: 구름많음
# 최저기온: 7
# 최고기온: 18
#
# 도시: 강릉
# 날씨: 구름많음
# 최저기온: 11
# 최고기온: 19
#
# 도시: 대전
# 날씨: 구름많음
# 최저기온: 10
# 최고기온: 18
#
# 도시: 세종
# 날씨: 구름많음
# 최저기온: 8
# 최고기온: 18
#
# 도시: 홍성
# 날씨: 구름많음
# 최저기온: 8
# 최고기온: 18
#
# 도시: 청주
# 날씨: 구름많음
# 최저기온: 10
# 최고기온: 18
#
# 도시: 충주
# 날씨: 구름많음
# 최저기온: 6
# 최고기온: 18
#
# 도시: 영동
# 날씨: 구름많음
# 최저기온: 7
# 최고기온: 18
#
# 도시: 광주
# 날씨: 흐리고 비
# 최저기온: 12
# 최고기온: 18
#
# 도시: 목포
# 날씨: 흐리고 비
# 최저기온: 13
# 최고기온: 18
#
# 도시: 여수
# 날씨: 흐리고 비
# 최저기온: 14
# 최고기온: 17
#
# 도시: 순천
# 날씨: 흐리고 비
# 최저기온: 13
# 최고기온: 20
#
# 도시: 광양
# 날씨: 흐리고 비
# 최저기온: 13
# 최고기온: 17
#
# 도시: 나주
# 날씨: 흐리고 비
# 최저기온: 10
# 최고기온: 18
#
# 도시: 전주
# 날씨: 구름많음
# 최저기온: 11
# 최고기온: 18
#
# 도시: 군산
# 날씨: 구름많음
# 최저기온: 10
# ...

# %%
# !pip install flask   
#!는 시스템 명령을 수행하는 것
